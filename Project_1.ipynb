# %%
import pandas as pd
metro = pd.read_csv(r'C:\Users\lee\Desktop\빅데이터수업\프로젝트\metro_1.CSV',encoding='cp949')
metro.head(22)
# Out:
#                             구분            1호선              2호선            3호선  \
# 0                          구 간         서울~청량리        성수~성수(지선)          지축~오금
# 1                     영업거리(km)            7.8             60.2           38.2
# 2                      역 수 (개)             10               50             34
# 3                      소요시간(분)             18         90(9/11)           67.5
# 4                     보유차량수(칸)            160              794            490
# 5               열차편성수(1편성당 칸수)         16(10)       84(10/6/4)         49(10)
# 6                   표정속도(km/h)             26  32.5(36.0/32.7)             34
# 7              열차주행거리(평일 km/일)         5083.4          25607.6        13454.7
# 8                 운행 시격_RH(출근)            3.5    2.5(7.0/10.0)              3
# 9                 운행 시격_NH(평시)              5   5.5(10.0/10.0)            6.5
# 10                    운행 횟수_평일  514(S86/K428)     947(517/430)  362(S268/K94)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as pl
import matplotlib as mpl

# %%
metro = pd.read_csv(r'C:\Users\lee\Desktop\빅데이터수업\프로젝트\metro_1.csv',encoding='cp949')

# %%
metro
# Out:
#                             구분            1호선              2호선            3호선  \
# 0                          구 간         서울~청량리        성수~성수(지선)          지축~오금
# 1                     영업거리(km)            7.8             60.2           38.2
# 2                      역 수 (개)             10               50             34
# 3                      소요시간(분)             18         90(9/11)           67.5
# 4                     보유차량수(칸)            160              794            490
# 5               열차편성수(1편성당 칸수)         16(10)       84(10/6/4)         49(10)
# 6                   표정속도(km/h)             26  32.5(36.0/32.7)             34
# 7              열차주행거리(평일 km/일)         5083.4          25607.6        13454.7
# 8                 운행 시격_RH(출근)            3.5    2.5(7.0/10.0)              3
# 9                 운행 시격_NH(평시)              5   5.5(10.0/10.0)            6.5
# 10                    운행 횟수_평일  514(S86/K428)     947(517/430)  362(S268/K94)
# ...

# %%
metro = pd.read_csv('metro_1.csv', index_col='구분', encoding='euc-kr')
metro
# Out:
#                                       1호선              2호선            3호선  \
# 구분
# 구 간                                서울~청량리        성수~성수(지선)          지축~오금
# 영업거리(km)                              7.8             60.2           38.2
# 역 수 (개)                                10               50             34
# 소요시간(분)                                18         90(9/11)           67.5
# 보유차량수(칸)                              160              794            490
# 열차편성수(1편성당 칸수)                     16(10)       84(10/6/4)         49(10)
# 표정속도(km/h)                             26  32.5(36.0/32.7)             34
# 열차주행거리(평일 km/일)                    5083.4          25607.6        13454.7
# 운행 시격_RH(출근)                          3.5    2.5(7.0/10.0)              3
# 운행 시격_NH(평시)                            5   5.5(10.0/10.0)            6.5
# 운행 횟수_평일                    514(S86/K428)     947(517/430)  362(S268/K94)
# 운행 횟수_휴일                    464(S76/K388)     853(435/418)  350(S278/K72)
# ...

# %%
#data = metro.iloc[idx,:]
stat_data = metro.iloc[2]

# %%
stat_data
# Out:
# 1호선          10
# 2호선          50
# 3호선          34
# 4호선          26
# 5호선          56
# 6호선          39
# 7호선          51
# 8호선          17
# 9호선 2·3단계    13
# Name: 역 수 (개), dtype: object

# %%
stat_df = metro.loc[['역 수 (개)']].apply(pd.to_numeric)
stat_df

#df_users[['Views', 'Reputation']] = df_users[['Views','Reputation']].apply(pd.to_numeric) 숫자화 시키기
# Out:
#          1호선  2호선  3호선  4호선  5호선  6호선  7호선  8호선  9호선 2·3단계
# 구분
# 역 수 (개)   10   50   34   26   56   39   51   17         13

# %%
ax = stat_df.plot(kind='bar', title ="호선별 역 개수",figsize=(15,10),legend=True, fontsize=12)
ax.set_xlabel("",fontsize=12)
ax.set_ylabel("역 개수",fontsize=12)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
km_df = metro.loc[['영업거리(km)']].apply(pd.to_numeric)
km_df
# Out:
#           1호선   2호선   3호선   4호선   5호선   6호선   7호선   8호선  9호선 2·3단계
# 구분
# 영업거리(km)  7.8  60.2  38.2  31.7  59.8  36.4  57.1  17.7       13.6

# %%
ax = km_df.plot(kind='bar', title ="운행 거리",figsize=(15,10),legend=True, fontsize=12)
ax.set_xlabel("",fontsize=12)
ax.set_ylabel("km",fontsize=12)
# Out:
# Text(0, 0.5, 'km')

# %%
df = pd.read_csv('metro.csv', index_col='구분', encoding='euc-kr')
df
# Out:
#                     구 간  영업거리(km)  역 수 (개)          소요시간(분)  보유차량수(칸)  \
# 구분
# 1호선              서울~청량리       7.8       10               18       160
# 2호선           성수~성수(지선)      60.2       50         90(9/11)       794
# 3호선               지축~오금      38.2       34             67.5       490
# 4호선             당고개~남태령      31.7       26               53       459
# 5호선        방화~하남검단산(마천)      59.8       56      109.5(87.5)       640
# 6호선             응암순환~신내      36.4       39             73.8       312
# 7호선             장암~부평구청      57.1       51            104.5       577
# 8호선               암사~모란      17.7       17             31.5       120
# 9호선 2·3단계     언주~중앙보훈병원      13.6       13  일반: 28/급행: 20.5        54
#
#           열차편성수(1편성당 칸수)         표정속도(km/h)  열차주행거리(평일 km/일)  \
# 구분
# 1호선               16(10)                 26           5083.4
# 2호선           84(10/6/4)    32.5(36.0/32.7)          25607.6
# 3호선               49(10)                 34          13454.7
# ...

# %%
df.loc['1호선']
# Out:
# 구 간                       서울~청량리
# 영업거리(km)                     7.8
# 역 수 (개)                       10
# 소요시간(분)                       18
# 보유차량수(칸)                     160
# 열차편성수(1편성당 칸수)            16(10)
# 표정속도(km/h)                    26
# 열차주행거리(평일 km/일)           5083.4
# 운행 시격_RH(출근)                 3.5
# 운행 시격_NH(평시)                   5
# 운행 횟수_평일           514(S86/K428)
# 운행 횟수_휴일           464(S76/K388)
# Name: 1호선, dtype: object

# %%
df.loc[['1호선','2호선']]
# Out:
#            구 간  영업거리(km)  역 수 (개)   소요시간(분)  보유차량수(칸) 열차편성수(1편성당 칸수)  \
# 구분
# 1호선     서울~청량리       7.8       10        18       160         16(10)
# 2호선  성수~성수(지선)      60.2       50  90(9/11)       794     84(10/6/4)
#
#           표정속도(km/h)  열차주행거리(평일 km/일)   운행 시격_RH(출근)    운행 시격_NH(평시)  \
# 구분
# 1호선               26           5083.4            3.5               5
# 2호선  32.5(36.0/32.7)          25607.6  2.5(7.0/10.0)  5.5(10.0/10.0)
#
#           운행 횟수_평일       운행 횟수_휴일
# 구분
# 1호선  514(S86/K428)  464(S76/K388)
# 2호선   947(517/430)   853(435/418)

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['C:\\WINDOWS\\Fonts\\eurr____.ttf',
#  'C:\\Windows\\Fonts\\Artifakt Element Bold.ttf',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\WINDOWS\\Fonts\\ARIALNB.TTF',
#  'C:\\WINDOWS\\Fonts\\l_10646.ttf',
#  'C:\\WINDOWS\\Fonts\\webdings.ttf',
#  'C:\\WINDOWS\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\HANDotumB.ttf',
#  'C:\\Windows\\Fonts\\SitkaI.ttc',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\WINDOWS\\Fonts\\GARAIT.TTF',
#  'C:\\Windows\\Fonts\\MTEXTRA.TTF',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\WINDOWS\\Fonts\\monosbi.ttf',
#  'C:\\WINDOWS\\Fonts\\Artifakt Element Italic.ttf',
#  'C:\\WINDOWS\\Fonts\\monotxt_.ttf',
#  'C:\\WINDOWS\\Fonts\\H2MKPB.TTF',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\corbell.ttf',
#  'C:\\WINDOWS\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\syastro_.ttf',
#  'C:\\WINDOWS\\Fonts\\HANBatangExtB.ttf',
#  'C:\\WINDOWS\\Fonts\\italict_.ttf',
# ...
